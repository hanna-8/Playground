# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel(open('d:/MyCode/Playground/eMeL/datas/201702_AUTOTURISM_DETALIAT.xlsx','rb'), sheetname='201702_AUTOTURISM_DETALIAT')

# %%
df.shape
# Out:
# (75265, 30)

# %%
df.head()
# Out:
#   Vehicule noi si second hand inmatriculate in luna curenta     Unnamed: 1  \
# 0                                              Judet                 Marca
# 1                                             County         Vehicle_brand
# 2                                               ALBA            ALFA ROMEO
# 3                                               ALBA            ALFA ROMEO
# 4                                               ALBA            ALFA ROMEO
#
#    Unnamed: 2       Unnamed: 3     Unnamed: 4              Unnamed: 5  \
# 0         Tip         Extensie       Versiune     Denumire comerciala
# 1  Brand_type  Brand_extension  Brand_Version  Commercial_description
# 2         932            A2A00             05                     156
# 3         932            A2A00             05                     156
# 4         932            A2C00            44E                     156
#
#      Unnamed: 6     Unnamed: 7        Unnamed: 8             Unnamed: 9  \
# ...

# %% [markdown]
# ### Set title row. Romanian :).

# %%
new_header = df.iloc[0]
df = df[2:]
df.columns = new_header
df.head()
# Out:
# 16  ALBA  AUDI  4B  AAVFF1  FM6EACR92P       A6    AC BREAK  NaN  5  1896 ...  \
# 18  ALBA  AUDI  4B  ABDGF1  FM6EA0R92P       A6    AC BREAK  NaN  5  2496 ...
# 19  ALBA  AUDI  4B  HBAUQ1  QA5VACR73S  ALLROAD    AC BREAK  NaN  5  2496 ...
# 20  ALBA  AUDI  4B  LAGAF1         NaN       A6  AA BERLINA  NaN  5  2393 ...
# 21  ALBA  AUDI  4B  LAWTF1  FM52EMR920       A6  AA BERLINA  NaN  5  1781 ...
# 22  ALBA  AUDI  4B  LAWXF1  FM52FCR92O       A6  AA BERLINA  NaN  5  1896 ...
#
# 16  PERSOANA  PROPRIETAR UNIC  NaN  NaN  NaN  IP - VEHICUL UZAT IMPORTAT  \
# 18  PERSOANA  PROPRIETAR UNIC  NaN  NaN  NaN  IP - VEHICUL UZAT IMPORTAT
# 19  PERSOANA  PROPRIETAR UNIC  NaN  NaN  NaN  IP - VEHICUL UZAT IMPORTAT
# 20  PERSOANA  PROPRIETAR UNIC  NaN  NaN  NaN  IP - VEHICUL UZAT IMPORTAT
# 21  PERSOANA  PROPRIETAR UNIC  NaN  NaN  NaN  IP - VEHICUL UZAT IMPORTAT
# 22  PERSOANA  PROPRIETAR UNIC  NaN  NaN  NaN  IP - VEHICUL UZAT IMPORTAT
#
# 16  09.12.2003  03.02.2017   M1  1
# ...
